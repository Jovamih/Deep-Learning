# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"/content/DATA-PRUEBA_CALIFICACIONES  2017-2019-FISI.xlsx",sheet_name=None)

# %%
data_2017=pd.DataFrame(data['2017'])
data_2018=pd.DataFrame(data['2018'])
data_2019=pd.DataFrame(data['2019'])

data_calif=pd.concat([data_2017,data_2018,data_2019],axis=0)

# %%
data_calif.head()
# Out:
#    cod_semestre  cod_facultad  ...  cod_alumno val_calific_final
# 0         20171            20  ...    06200023                11
# 1         20171            20  ...    05200188                12
# 2         20171            20  ...    08200095                15
# 3         20171            20  ...    07200077                13
# 4         20171            20  ...    08200198                12
#
# [5 rows x 7 columns]

# %%
#exploracion de datos
data_calif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31466 entries, 0 to 7534
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cod_semestre       31466 non-null  int64
#  1   cod_facultad       31466 non-null  int64
#  2   cod_escuela        31466 non-null  int64
#  3   cod_plan           31466 non-null  object
#  4   cod_asignatura     31466 non-null  object
#  5   cod_alumno         31466 non-null  object
#  6   val_calific_final  31466 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 1.9+ MB

# %%
sns.pairplot(data_calif,hue='cod_escuela')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
report=data_calif['cod_facultad'].value_counts()
print(report)
data_calif['cod_facultad'].value_counts().plot(kind="pie")
plt.show()
# Out:
# 20    31466
# Name: cod_facultad, dtype: int64

# %%
report=data_calif['cod_semestre'].value_counts()
print(report)
data_calif['cod_semestre'].value_counts().plot(kind="pie")
plt.show()
# Out:
# 20171    8835
# 20172    8175
# 20192    7535
# 20182    6921
# Name: cod_semestre, dtype: int64

# %%
report=data_calif['cod_plan'].value_counts()
print(report)
data_calif['cod_plan'].value_counts().plot(kind="pie")
plt.show()
# Out:
# 2014      7637
# 2014      7250
# 2009      5118
# 2015      3589
# 2015      3000
# 2009      2272
# 2018      1703
# 2002       648
# 2002       231
# PCONV       18
# Name: cod_plan, dtype: int64

# %%
report=data_calif['cod_escuela'].value_counts()
print(report)
data_calif['cod_escuela'].value_counts().plot(kind="pie")
plt.show()
# Out:
# 1    21074
# 2    10392
# Name: cod_escuela, dtype: int64

# %%
report=data_calif['cod_asignatura'].value_counts()
print(report)
data_calif['cod_asignatura'].value_counts().plot(kind="pie")
plt.show()
# Out:
# 2010401     332
# 2010302     316
# 2010104     314
# 2010403     301
# 2010201     291
#            ...
# 202009        1
# 202004        1
# 2011101       1
# 2020403       1
# 201008        1
# Name: cod_asignatura, Length: 466, dtype: int64

# %%
sns.displot(data_calif,x='val_calific_final',kde=True)

# %%
#resumen
#Variables objetivo: Calificaciones
#caracteristicas: Los demas datos excepto codigo
#las columnas cod_semestre,cod_plan,cod_escuela,cod_asignatura son categoricas por lo que necesitan una codificacion de variables
#las columnas de codigo

# %%
#Preparacion de datos
data_calif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31466 entries, 0 to 7534
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cod_semestre       31466 non-null  int64
#  1   cod_facultad       31466 non-null  int64
#  2   cod_escuela        31466 non-null  int64
#  3   cod_plan           31466 non-null  object
#  4   cod_asignatura     31466 non-null  object
#  5   cod_alumno         31466 non-null  object
#  6   val_calific_final  31466 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 1.9+ MB

# %%
#primero eliminamos los valores innecesarios
data_calif.drop(columns=["cod_alumno","cod_facultad"],inplace=True)
data_calif.head()
# Out:
#    cod_semestre  cod_escuela cod_plan cod_asignatura  val_calific_final
# 0         20171            1   2002         201101                   11
# 1         20171            1   2002         201101                   12
# 2         20171            1   2002         201101                   15
# 3         20171            1   2002         201101                   13
# 4         20171            1   2002         201101                   12

# %%
#primero codificamos los valores categoricos
data_calif=pd.get_dummies(data_calif,columns=["cod_escuela","cod_semestre","cod_plan","cod_asignatura"])

# %%
#luego ya tenemos los datos procesados para la clasificacion y regresion o agrupamiento y redes neuronales
data_calif.head()
# Out:
#    val_calific_final  ...  cod_asignatura_20W1005
# 0                 11  ...                        0
# 1                 12  ...                        0
# 2                 15  ...                        0
# 3                 13  ...                        0
# 4                 12  ...                        0
#
# [5 rows x 483 columns]

# %%
#separacion de la variable objetivo de las caracteristicas
X=data_calif.drop('val_calific_final',axis=1).values
y=data_calif['val_calific_final'].values

# %% [markdown]
# ## IMPLEMENTACION DEL ALGORITMO DE CLASIFICACION PARA PREDICCION DE RENDIMIENTO ACADEMICO

# %%
#segmentar a los alumnos por sus calificaciones
grado=['D','A','B','MB','E']
y=pd.cut(y,bins=[0,11,13,16,18,21],labels=grado,right=False)
#codificacion de variable objetivo
from sklearn.preprocessing import LabelEncoder
encoder_grado=LabelEncoder()
y=encoder_grado.fit_transform(y.astype('str')).astype('int64')
y_kmeans=y

# %%
#separamos los datos en set de entrenamiento y test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,shuffle=True,stratify=y)
#escojemos las maquinas de soporte vectorial

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, StratifiedKFold
#instanciamos el modelo
model_clasif=RandomForestClassifier(n_estimators=1000,max_depth=5,class_weight='balanced')
#entrenamos el modelo
kf=StratifiedKFold(n_splits=10,shuffle=True)
result=cross_val_score(model_clasif,x_train,y_train,cv=kf,n_jobs=-1)
#model_clasif.fit(x_train,y_train)

# %%
result.mean()
# Out:
# 0.3677507098527604

# %%
model_clasif.fit(x_train,y_train);

# %%
model_clasif.score(x_test,y_test)
# Out:
# 0.36747881355932205

# %%
#ahora evaluaremos el rendimiento del modelo
y_pred=model_clasif.predict(x_test)
from sklearn.metrics import confusion_matrix, classification_report

report=classification_report(y_test,y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.30      0.33      2731
#            1       0.48      0.35      0.40      3489
#            2       0.34      0.53      0.41      1949
#            3       0.13      0.55      0.21       242
#            4       0.40      0.26      0.31      1029
#
#     accuracy                           0.37      9440
#    macro avg       0.35      0.40      0.33      9440
# weighted avg       0.40      0.37      0.37      9440

# %%
pd.Series(y_test).value_counts().plot(kind='pie')
plt.title("Distribucion de resultados en los datos de entrenamiento")

plt.show()

# %%
pd.Series(y_pred).value_counts().plot(kind='pie')
plt.title("Distribucion de resultados esperados en los datos de prueba")

plt.show()

# %%
conf=confusion_matrix(y_test,y_pred)
sns.heatmap(conf,annot=True,fmt='0.2f',square=True)

# %%
#guardado del modelo de machine learning
import joblib
joblib.dump(model_clasif,"modelo_clasificacion_rendimiento.pkl")
# Out:
# ['modelo_clasificacion_rendimiento.pkl']

# %% [markdown]
# MODELO DE REGRESION PARA LA PREDICCION DEL RENDIMIENTO ACADEMICO

# %%
#separacion de la variable objetivo de las caracteristicas
X=data_calif.drop('val_calific_final',axis=1).values
y=data_calif['val_calific_final'].values
#Separamos los datos en entrenamiento y test
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,shuffle=True)

# %%
#seleccion del modelo de machine learning
from sklearn.svm import SVR

model_regressor=SVR(C=200,gamma=0.001)

# %%
model_regressor.fit(x_train,y_train)
# Out:
# SVR(C=200, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.001,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
model_regressor.score(x_test,y_test)
# Out:
# 0.1320068961003501

# %%
y_pred=model_regressor.predict(x_test)
#evaluacion del modelo
from sklearn.metrics import mean_squared_error,r2_score
result=mean_squared_error(y_test,y_pred)
print("Error cuadratico medio ={0}",result)
result=r2_score(y_test,y_pred)
print("R2 Score ={0}",result)
# Out:
# Error cuadratico medio ={0} 14.388796915465475
# R2 Score ={0} 0.1320068961003501

# %%
def plot_compare(x1,x2):
  points=range(1,x1.shape[0]+1)
  plt.plot(x1,'go',label='Y verdadero')
  plt.plot(x2,'ro',label='Y predecido')
  plt.legend(loc='best')
  plt.show()

# %%
#puntos esparcidos
plot_compare(y_test,y_pred)

# %%
pd.DataFrame({
    "Resultado Real": y_test,
    "Resultado Predecido":y_pred
})
# Out:
#       Resultado Real  Resultado Predecido
# 0                  2            14.900093
# 1                 12            13.173048
# 2                 15            15.099764
# 3                 11            13.100082
# 4                 11            10.910021
# ...              ...                  ...
# 9435              15            14.899776
# 9436               0            10.899751
# 9437              11            10.899751
# 9438              13            14.887764
# 9439              14            13.359956
#
# [9440 rows x 2 columns]

# %%
joblib.dump(model_regressor,"model_regressor_rendimiento.pkl")
# Out:
# ['model_regressor_rendimiento.pkl']

# %%
y_test.max()
# Out:
# 20

# %% [markdown]
# ## MODELO DE APRENDIZAJE NO SUPERVISADO PARA ENCONTRAR PATRONES EN EL RENDIMIENTO ACADEMICO

# %%
#como se trata de aprendizaje no supervisado ya no contaremos con las variables de salida
#separacion de la variable objetivo de las caracteristicas
X=data_calif.drop('val_calific_final',axis=1).values

from sklearn.cluster import MiniBatchKMeans

score=[]
#seleccionamos los mejores grupos
for N in range(1,21):
  cluster=MiniBatchKMeans(n_clusters=N,
                          random_state=42,
                          batch_size=16
                          )
  score.append(cluster.fit(X).score(X))

# %%
plt.plot(range(1,len(score)+1),score)
plt.xlabel("Numero de clusteres")
plt.ylabel("Score")
plt.title("Curva de puntaje")
# Out:
# Text(0.5, 1.0, 'Curva de puntaje')

# %%
#en este grafico que se obtiene un mayor rendimiento con 17 clusteres o grupos
#es decir se encuentran patrones optimos para esa cantidad de grupos
model_cluster=MiniBatchKMeans(n_clusters=17,
                              random_state=42,
                              batch_size=16)
model_cluster.fit(X);

# %%
#ahora observamos los centros de datos
model_cluster.labels_
# Out:
# array([6, 6, 6, ..., 2, 2, 2], dtype=int32)

# %%
labels_cluster=model_cluster.labels_
dat=pd.DataFrame(pd.Series(labels_cluster).value_counts(),columns=['No. Elementos'])
print(dat)
pd.Series(labels_cluster).value_counts().plot(kind='pie')
plt.title("Distribucion de clusteres")
plt.show()
# Out:
#     No. Elementos
# 3            3996
# 12           3853
# 1            3784
# 7            3726
# 0            2761
# 2            2464
# 6            2030
# 8            1854
# 9            1630
# 11           1570
# 10           1039
# 5             982
# 4             704
# 15            690
# 16            231
# 13             93
# 14             59

# %%
#implementacion del modelo
joblib.dump(model_cluster,"modelo_cluster_rendimiento.pkl")
# Out:
# ['modelo_cluster_rendimiento.pkl']

# %%
#luego paso la variable y_kmeans para el uso de redes neuronales
y=y_kmeans #paso una variable codificada en categorica

# %% [markdown]
# ## MODELO DE APRENDIZAJE POR REFUERZO BASADO EN REDES NEURONALES PARA PREDECIR EL RENDIMIENTO ACADEMICO

# %%
#separacion de la variable objetivo de las caracteristicas
X=data_calif.drop('val_calific_final',axis=1).values
y=data_calif['val_calific_final'].values

# %%
#segmentar a los alumnos por sus calificaciones
grado=['D','A','B','MB','E']
y=pd.cut(y,bins=[0,11,13,16,18,21],labels=grado,right=False)
#codificacion de variable objetivo
from sklearn.preprocessing import LabelEncoder
encoder_grado=LabelEncoder()
y=encoder_grado.fit_transform(y.astype('str')).astype('int64')

# %%
#importamos las librerias necesarias
from tensorflow import keras
#primero construimos una red neuronal basado en la API functional
#Entradas: Arreglo de tamaño n_caracterisiticas = x_train.shape[1]
n_caracteristicas=X.shape[1]
def build_model():
  input=keras.Input(shape=(n_caracteristicas,))       #Tamaño de datos de entrada
  x=keras.layers.Dense(512,activation="relu")(input)  #1era capa de 512 neuronas
  x=keras.layers.Dense(128,activation="relu")(x)      #2da capa de 128 neuronas
  output=keras.layers.Dense(5,activation="softmax")(x)   #capa de salida de tamaño 6 con activacion softmax para clasificacion 
  model=keras.Model(inputs=input,outputs=output)      #
  #Se realiza la compilacion del modelo
  model.compile(loss="categorical_crossentropy",
                optimizer="rmsprop",
                metrics=["accuracy"])
  return model

# %%
#ahora necesitamos codificar la variable Y como OneHotEncoding para que acepte la probabilidad por clase
#ejem: [0,0,0,0,01]
y=to_categorical(y,num_classes=5)
#Separamos los datos en entrenamiento y test
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,shuffle=True,stratify=y)
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=0.2,random_state=42,shuffle=True,stratify=y_train)
from keras.utils import to_categorical

# %%
#ahora realizamos las graficas de puntajes de perdida y precision
def plot_loss(history):
  epochs=range(1,len(history['loss'])+1)
  plt.plot(epochs,history['loss'],'bo-',label='Loss train')
  plt.plot(epochs,history['val_loss'],'ro-',label='Loss validation')
  plt.xlabel("epochs")
  plt.ylabel("Loss")
  plt.legend(loc='best')
  plt.grid(True)
  plt.show()

# %%
def plot_accuracy(history):
  epochs=range(1,len(history['accuracy'])+1)
  plt.plot(epochs,history['accuracy'],'bo-',label='Accuracy train')
  plt.plot(epochs,history['val_accuracy'],'ro-',label='Accuracy validation')
  plt.xlabel("epochs")
  plt.ylabel("Accuracy")
  plt.legend(loc='best')
  plt.grid(True)
  plt.show()

# %%
#procedemos a entrenar el modelo
model_deep=build_model()
history=model_deep.fit(x_train,y_train,batch_size=32,epochs=100,validation_data=(x_val,y_val))
# Out:
# Epoch 1/100
# 551/551 [==============================] - 4s 6ms/step - loss: 1.3345 - accuracy: 0.3950 - val_loss: 1.2309 - val_accuracy: 0.4401
# Epoch 2/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1828 - accuracy: 0.4810 - val_loss: 1.2148 - val_accuracy: 0.4485
# Epoch 3/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1634 - accuracy: 0.4883 - val_loss: 1.1974 - val_accuracy: 0.4562
# Epoch 4/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1363 - accuracy: 0.4969 - val_loss: 1.1943 - val_accuracy: 0.4601
# Epoch 5/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1263 - accuracy: 0.5092 - val_loss: 1.2025 - val_accuracy: 0.4630
# Epoch 6/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1298 - accuracy: 0.5031 - val_loss: 1.2060 - val_accuracy: 0.4555
# Epoch 7/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1201 - accuracy: 0.5106 - val_loss: 1.2022 - val_accuracy: 0.4546
# Epoch 8/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1162 - accuracy: 0.5021 - val_loss: 1.2111 - val_accuracy: 0.4567
# Epoch 9/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1150 - accuracy: 0.5152 - val_loss: 1.2116 - val_accuracy: 0.4623
# Epoch 10/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1127 - accuracy: 0.5163 - val_loss: 1.2104 - val_accuracy: 0.4507
# Epoch 11/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1160 - accuracy: 0.5082 - val_loss: 1.2209 - val_accuracy: 0.4582
# Epoch 12/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1091 - accuracy: 0.5172 - val_loss: 1.2188 - val_accuracy: 0.4596
# Epoch 13/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1058 - accuracy: 0.5171 - val_loss: 1.2148 - val_accuracy: 0.4612
# Epoch 14/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1048 - accuracy: 0.5087 - val_loss: 1.2265 - val_accuracy: 0.4637
# Epoch 15/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1053 - accuracy: 0.5142 - val_loss: 1.2252 - val_accuracy: 0.4521
# Epoch 16/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1049 - accuracy: 0.5142 - val_loss: 1.2260 - val_accuracy: 0.4653
# Epoch 17/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1081 - accuracy: 0.5178 - val_loss: 1.2433 - val_accuracy: 0.4685
# Epoch 18/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1092 - accuracy: 0.5130 - val_loss: 1.2310 - val_accuracy: 0.4635
# Epoch 19/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1181 - accuracy: 0.5137 - val_loss: 1.2454 - val_accuracy: 0.4555
# Epoch 20/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1147 - accuracy: 0.5089 - val_loss: 1.2450 - val_accuracy: 0.4582
# Epoch 21/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1155 - accuracy: 0.5119 - val_loss: 1.2370 - val_accuracy: 0.4612
# Epoch 22/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1099 - accuracy: 0.5134 - val_loss: 1.2274 - val_accuracy: 0.4601
# Epoch 23/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1126 - accuracy: 0.5125 - val_loss: 1.2449 - val_accuracy: 0.4637
# Epoch 24/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1120 - accuracy: 0.5135 - val_loss: 1.2502 - val_accuracy: 0.4626
# Epoch 25/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1230 - accuracy: 0.5108 - val_loss: 1.2496 - val_accuracy: 0.4569
# Epoch 26/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1235 - accuracy: 0.5067 - val_loss: 1.2661 - val_accuracy: 0.4589
# Epoch 27/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1242 - accuracy: 0.4998 - val_loss: 1.2692 - val_accuracy: 0.4578
# Epoch 28/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1193 - accuracy: 0.5171 - val_loss: 1.2436 - val_accuracy: 0.4621
# Epoch 29/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1164 - accuracy: 0.5154 - val_loss: 1.2718 - val_accuracy: 0.4519
# Epoch 30/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1116 - accuracy: 0.5117 - val_loss: 1.2621 - val_accuracy: 0.4626
# Epoch 31/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1228 - accuracy: 0.4998 - val_loss: 1.2573 - val_accuracy: 0.4641
# Epoch 32/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1213 - accuracy: 0.5070 - val_loss: 1.2711 - val_accuracy: 0.4517
# Epoch 33/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1300 - accuracy: 0.5056 - val_loss: 1.2925 - val_accuracy: 0.4628
# Epoch 34/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1260 - accuracy: 0.5070 - val_loss: 1.2958 - val_accuracy: 0.4551
# Epoch 35/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1257 - accuracy: 0.5121 - val_loss: 1.2834 - val_accuracy: 0.4632
# Epoch 36/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1268 - accuracy: 0.5115 - val_loss: 1.3028 - val_accuracy: 0.4380
# Epoch 37/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1267 - accuracy: 0.5074 - val_loss: 1.2781 - val_accuracy: 0.4451
# Epoch 38/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1299 - accuracy: 0.5063 - val_loss: 1.2900 - val_accuracy: 0.4544
# Epoch 39/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1298 - accuracy: 0.5095 - val_loss: 1.2979 - val_accuracy: 0.4544
# Epoch 40/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1410 - accuracy: 0.5037 - val_loss: 1.3125 - val_accuracy: 0.4626
# Epoch 41/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1293 - accuracy: 0.5069 - val_loss: 1.2944 - val_accuracy: 0.4637
# Epoch 42/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1215 - accuracy: 0.5150 - val_loss: 1.2941 - val_accuracy: 0.4646
# Epoch 43/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1378 - accuracy: 0.5049 - val_loss: 1.2887 - val_accuracy: 0.4626
# Epoch 44/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1420 - accuracy: 0.5045 - val_loss: 1.3135 - val_accuracy: 0.4628
# Epoch 45/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1425 - accuracy: 0.5111 - val_loss: 1.3010 - val_accuracy: 0.4603
# Epoch 46/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1406 - accuracy: 0.5060 - val_loss: 1.3049 - val_accuracy: 0.4653
# Epoch 47/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1473 - accuracy: 0.4910 - val_loss: 1.3131 - val_accuracy: 0.4517
# Epoch 48/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1270 - accuracy: 0.5171 - val_loss: 1.2986 - val_accuracy: 0.4576
# Epoch 49/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1370 - accuracy: 0.5086 - val_loss: 1.3319 - val_accuracy: 0.4530
# Epoch 50/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1345 - accuracy: 0.5077 - val_loss: 1.3465 - val_accuracy: 0.4637
# Epoch 51/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1445 - accuracy: 0.5041 - val_loss: 1.3304 - val_accuracy: 0.4503
# Epoch 52/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1326 - accuracy: 0.5117 - val_loss: 1.3122 - val_accuracy: 0.4537
# Epoch 53/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1421 - accuracy: 0.5077 - val_loss: 1.3221 - val_accuracy: 0.4580
# Epoch 54/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1578 - accuracy: 0.5010 - val_loss: 1.3712 - val_accuracy: 0.4551
# Epoch 55/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1480 - accuracy: 0.5067 - val_loss: 1.3268 - val_accuracy: 0.4578
# Epoch 56/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1517 - accuracy: 0.4982 - val_loss: 1.3561 - val_accuracy: 0.4616
# Epoch 57/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1580 - accuracy: 0.4978 - val_loss: 1.3247 - val_accuracy: 0.4555
# Epoch 58/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1529 - accuracy: 0.5028 - val_loss: 1.3271 - val_accuracy: 0.4589
# Epoch 59/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1585 - accuracy: 0.4958 - val_loss: 1.3684 - val_accuracy: 0.4644
# Epoch 60/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1525 - accuracy: 0.5033 - val_loss: 1.3485 - val_accuracy: 0.4601
# Epoch 61/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1505 - accuracy: 0.5019 - val_loss: 1.4207 - val_accuracy: 0.4101
# Epoch 62/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1579 - accuracy: 0.5022 - val_loss: 1.4186 - val_accuracy: 0.4283
# Epoch 63/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1605 - accuracy: 0.5045 - val_loss: 1.3674 - val_accuracy: 0.4433
# Epoch 64/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1659 - accuracy: 0.5028 - val_loss: 1.3610 - val_accuracy: 0.4580
# Epoch 65/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1552 - accuracy: 0.5060 - val_loss: 1.3653 - val_accuracy: 0.4548
# Epoch 66/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1589 - accuracy: 0.5044 - val_loss: 1.3735 - val_accuracy: 0.4439
# Epoch 67/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1645 - accuracy: 0.5006 - val_loss: 1.3602 - val_accuracy: 0.4514
# Epoch 68/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1453 - accuracy: 0.5062 - val_loss: 1.3566 - val_accuracy: 0.4507
# Epoch 69/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1581 - accuracy: 0.5075 - val_loss: 1.3590 - val_accuracy: 0.4551
# Epoch 70/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1583 - accuracy: 0.5052 - val_loss: 1.4084 - val_accuracy: 0.4666
# Epoch 71/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1657 - accuracy: 0.5019 - val_loss: 1.3604 - val_accuracy: 0.4601
# Epoch 72/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1605 - accuracy: 0.5013 - val_loss: 1.3764 - val_accuracy: 0.4542
# Epoch 73/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1709 - accuracy: 0.4946 - val_loss: 1.3843 - val_accuracy: 0.4546
# Epoch 74/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1795 - accuracy: 0.4934 - val_loss: 1.3806 - val_accuracy: 0.4510
# Epoch 75/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1638 - accuracy: 0.5033 - val_loss: 1.4055 - val_accuracy: 0.4562
# Epoch 76/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1784 - accuracy: 0.5014 - val_loss: 1.4324 - val_accuracy: 0.4650
# Epoch 77/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1711 - accuracy: 0.5025 - val_loss: 1.3726 - val_accuracy: 0.4673
# Epoch 78/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1732 - accuracy: 0.5064 - val_loss: 1.4260 - val_accuracy: 0.4530
# Epoch 79/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1732 - accuracy: 0.5029 - val_loss: 1.4644 - val_accuracy: 0.4038
# Epoch 80/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1732 - accuracy: 0.4980 - val_loss: 1.3865 - val_accuracy: 0.4626
# Epoch 81/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1581 - accuracy: 0.5044 - val_loss: 1.3714 - val_accuracy: 0.4610
# Epoch 82/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1646 - accuracy: 0.5086 - val_loss: 1.3832 - val_accuracy: 0.4673
# Epoch 83/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1891 - accuracy: 0.5011 - val_loss: 1.3678 - val_accuracy: 0.4619
# Epoch 84/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1740 - accuracy: 0.5082 - val_loss: 1.3729 - val_accuracy: 0.4537
# Epoch 85/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1780 - accuracy: 0.4971 - val_loss: 1.4025 - val_accuracy: 0.4380
# Epoch 86/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1878 - accuracy: 0.4927 - val_loss: 1.3812 - val_accuracy: 0.4546
# Epoch 87/100
# 551/551 [==============================] - 4s 7ms/step - loss: 1.1785 - accuracy: 0.5050 - val_loss: 1.3941 - val_accuracy: 0.4596
# Epoch 88/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1762 - accuracy: 0.5008 - val_loss: 1.3705 - val_accuracy: 0.4458
# Epoch 89/100
# 551/551 [==============================] - 3s 6ms/step - loss: 1.1785 - accuracy: 0.5071 - val_loss: 1.3910 - val_accuracy: 0.4589
# Epoch 90/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1733 - accuracy: 0.5040 - val_loss: 1.3761 - val_accuracy: 0.4632
# Epoch 91/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1759 - accuracy: 0.4979 - val_loss: 1.4415 - val_accuracy: 0.4476
# Epoch 92/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1710 - accuracy: 0.5004 - val_loss: 1.4226 - val_accuracy: 0.4374
# Epoch 93/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1871 - accuracy: 0.4975 - val_loss: 1.3886 - val_accuracy: 0.4614
# Epoch 94/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1899 - accuracy: 0.5041 - val_loss: 1.4067 - val_accuracy: 0.4451
# Epoch 95/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1782 - accuracy: 0.5022 - val_loss: 1.4118 - val_accuracy: 0.4480
# Epoch 96/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1763 - accuracy: 0.5018 - val_loss: 1.4209 - val_accuracy: 0.4448
# Epoch 97/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1798 - accuracy: 0.5054 - val_loss: 1.4217 - val_accuracy: 0.4532
# Epoch 98/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1842 - accuracy: 0.5044 - val_loss: 1.4306 - val_accuracy: 0.4265
# Epoch 99/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1740 - accuracy: 0.5005 - val_loss: 1.3781 - val_accuracy: 0.4589
# Epoch 100/100
# 551/551 [==============================] - 3s 5ms/step - loss: 1.1802 - accuracy: 0.5054 - val_loss: 1.3775 - val_accuracy: 0.4532

# %%
#history=_
plot_loss(history.history)

# %%
plot_accuracy(history.history)

# %%
#como existe un sobreajuste procedemos a reducir la complejidad del modelo
def build_model():
  input=keras.Input(shape=(n_caracteristicas,))       #Tamaño de datos de entrada
  x=keras.layers.Dense(512,activation="relu")(input)  #1era capa de 512 neuronas
  x=keras.layers.Dropout(0.5)(x)                       #capa de descersion
  x=keras.layers.Dense(64,activation="relu")(x)      #2da capa de 64 neuronas
  output=keras.layers.Dense(5,activation="softmax")(x)   #capa de salida de tamaño 5 con activacion softmax para clasificacion 
  model=keras.Model(inputs=input,outputs=output)      #
  #Se realiza la compilacion del modelo
  model.compile(loss="categorical_crossentropy",
                optimizer="rmsprop",
                metrics=["accuracy"])
  return model

# %%
#procedemos a entrenar el modelo para mejorar sus rendimiento
model_deep=build_model()
history=model_deep.fit(x_train,y_train,batch_size=256,epochs=50,validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 69/69 [==============================] - 2s 16ms/step - loss: 1.3973 - accuracy: 0.3702 - val_loss: 1.2910 - val_accuracy: 0.4317
# Epoch 2/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.2571 - accuracy: 0.4501 - val_loss: 1.2270 - val_accuracy: 0.4544
# Epoch 3/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.2123 - accuracy: 0.4618 - val_loss: 1.2115 - val_accuracy: 0.4557
# Epoch 4/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1850 - accuracy: 0.4789 - val_loss: 1.2002 - val_accuracy: 0.4585
# Epoch 5/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1669 - accuracy: 0.4856 - val_loss: 1.1964 - val_accuracy: 0.4655
# Epoch 6/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1546 - accuracy: 0.4887 - val_loss: 1.1925 - val_accuracy: 0.4603
# Epoch 7/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1376 - accuracy: 0.4924 - val_loss: 1.1889 - val_accuracy: 0.4630
# Epoch 8/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1372 - accuracy: 0.4979 - val_loss: 1.1915 - val_accuracy: 0.4687
# Epoch 9/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1234 - accuracy: 0.5005 - val_loss: 1.1893 - val_accuracy: 0.4605
# Epoch 10/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1383 - accuracy: 0.4986 - val_loss: 1.1892 - val_accuracy: 0.4628
# Epoch 11/50
# 69/69 [==============================] - 1s 15ms/step - loss: 1.1194 - accuracy: 0.5015 - val_loss: 1.1875 - val_accuracy: 0.4646
# Epoch 12/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1242 - accuracy: 0.5088 - val_loss: 1.1888 - val_accuracy: 0.4587
# Epoch 13/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1117 - accuracy: 0.4992 - val_loss: 1.1936 - val_accuracy: 0.4680
# Epoch 14/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1088 - accuracy: 0.5070 - val_loss: 1.1895 - val_accuracy: 0.4653
# Epoch 15/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1089 - accuracy: 0.5050 - val_loss: 1.1919 - val_accuracy: 0.4626
# Epoch 16/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1017 - accuracy: 0.5107 - val_loss: 1.1876 - val_accuracy: 0.4653
# Epoch 17/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1054 - accuracy: 0.5131 - val_loss: 1.1885 - val_accuracy: 0.4660
# Epoch 18/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1112 - accuracy: 0.5070 - val_loss: 1.1887 - val_accuracy: 0.4623
# Epoch 19/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0987 - accuracy: 0.5149 - val_loss: 1.1885 - val_accuracy: 0.4671
# Epoch 20/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0954 - accuracy: 0.5142 - val_loss: 1.1910 - val_accuracy: 0.4653
# Epoch 21/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1005 - accuracy: 0.5172 - val_loss: 1.1908 - val_accuracy: 0.4635
# Epoch 22/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0956 - accuracy: 0.5206 - val_loss: 1.1935 - val_accuracy: 0.4596
# Epoch 23/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0975 - accuracy: 0.5089 - val_loss: 1.1934 - val_accuracy: 0.4637
# Epoch 24/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0916 - accuracy: 0.5203 - val_loss: 1.1912 - val_accuracy: 0.4596
# Epoch 25/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0910 - accuracy: 0.5150 - val_loss: 1.1952 - val_accuracy: 0.4635
# Epoch 26/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0940 - accuracy: 0.5097 - val_loss: 1.1933 - val_accuracy: 0.4619
# Epoch 27/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0920 - accuracy: 0.5109 - val_loss: 1.1931 - val_accuracy: 0.4616
# Epoch 28/50
# 69/69 [==============================] - 1s 17ms/step - loss: 1.0862 - accuracy: 0.5178 - val_loss: 1.1944 - val_accuracy: 0.4596
# Epoch 29/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0823 - accuracy: 0.5208 - val_loss: 1.1939 - val_accuracy: 0.4605
# Epoch 30/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0830 - accuracy: 0.5171 - val_loss: 1.1948 - val_accuracy: 0.4612
# Epoch 31/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0932 - accuracy: 0.5099 - val_loss: 1.1964 - val_accuracy: 0.4637
# Epoch 32/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0841 - accuracy: 0.5165 - val_loss: 1.1963 - val_accuracy: 0.4616
# Epoch 33/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0831 - accuracy: 0.5219 - val_loss: 1.1971 - val_accuracy: 0.4612
# Epoch 34/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0802 - accuracy: 0.5202 - val_loss: 1.1967 - val_accuracy: 0.4619
# Epoch 35/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0814 - accuracy: 0.5155 - val_loss: 1.1959 - val_accuracy: 0.4607
# Epoch 36/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0933 - accuracy: 0.5140 - val_loss: 1.1999 - val_accuracy: 0.4601
# Epoch 37/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0827 - accuracy: 0.5137 - val_loss: 1.1976 - val_accuracy: 0.4616
# Epoch 38/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0816 - accuracy: 0.5243 - val_loss: 1.1958 - val_accuracy: 0.4630
# Epoch 39/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0842 - accuracy: 0.5204 - val_loss: 1.1981 - val_accuracy: 0.4603
# Epoch 40/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0823 - accuracy: 0.5182 - val_loss: 1.2002 - val_accuracy: 0.4639
# Epoch 41/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0831 - accuracy: 0.5174 - val_loss: 1.2028 - val_accuracy: 0.4635
# Epoch 42/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0700 - accuracy: 0.5244 - val_loss: 1.2003 - val_accuracy: 0.4589
# Epoch 43/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0757 - accuracy: 0.5250 - val_loss: 1.2021 - val_accuracy: 0.4601
# Epoch 44/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0754 - accuracy: 0.5194 - val_loss: 1.2015 - val_accuracy: 0.4655
# Epoch 45/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0890 - accuracy: 0.5146 - val_loss: 1.2033 - val_accuracy: 0.4619
# Epoch 46/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0746 - accuracy: 0.5200 - val_loss: 1.2030 - val_accuracy: 0.4585
# Epoch 47/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0809 - accuracy: 0.5198 - val_loss: 1.2028 - val_accuracy: 0.4628
# Epoch 48/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0821 - accuracy: 0.5175 - val_loss: 1.2024 - val_accuracy: 0.4571
# Epoch 49/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0838 - accuracy: 0.5137 - val_loss: 1.2066 - val_accuracy: 0.4639
# Epoch 50/50
# 69/69 [==============================] - 1s 14ms/step - loss: 1.0812 - accuracy: 0.5235 - val_loss: 1.2001 - val_accuracy: 0.4603

# %%
#ver los resultados
plot_loss(history.history)
plot_accuracy(history.history)

# %%
#realizamos la evaluacion del modelo
model_deep.evaluate(x_test,y_test)
# Out:
# 295/295 [==============================] - 1s 2ms/step - loss: 1.1923 - accuracy: 0.4749
# [1.1923376321792603, 0.47489407658576965]

# %%
y_pred=model_deep.predict(x_test)

# %%
y_pred=np.argmax(y_pred,axis=1)
y_test=np.argmax(y_test,axis=1)

# %%
from sklearn.metrics import classification_report,confusion_matrix
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.48      0.46      2731
#            1       0.51      0.64      0.57      3489
#            2       0.45      0.35      0.39      1949
#            3       0.34      0.15      0.21       242
#            4       0.43      0.22      0.29      1029
#
#     accuracy                           0.47      9440
#    macro avg       0.44      0.37      0.38      9440
# weighted avg       0.47      0.47      0.46      9440

# %%
conf= confusion_matrix(y_test,y_pred)
sns.heatmap(conf,fmt='0.2f',annot=True,square=True)

# %%
#implementacion del modelo
model_deep.save("model_deep_rendimiento")
# Out:
# INFO:tensorflow:Assets written to: model_deep_rendimiento/assets
